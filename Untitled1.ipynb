# %%
import tensorflow as tf
import matplotlib.pyplot as plt

import cv2
import numpy as np

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets\
.fashion_mnist.load_data()

class_names = ['T-shirt', 'trousers', 'pullover', 'dress', 'coat',
               'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i])
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1)
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1)

# %%
model = tf.keras.models.Sequential([
  
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
        ])

# %%
model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", 
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels,validation_data=(test_images, test_labels), epochs=10)
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
train_loss, train_acc = model.evaluate(train_images, train_labels, verbose=2)

print("train accuracy: ", train_acc)
print("Test accuracy: ", test_acc)
model.save("model.h5")
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 21s 354us/sample - loss: 0.8834 - accuracy: 0.8489 - val_loss: 0.3357 - val_accuracy: 0.8820
# Epoch 2/10
# 60000/60000 [==============================] - 18s 294us/sample - loss: 0.2873 - accuracy: 0.8960 - val_loss: 0.3397 - val_accuracy: 0.8852
# Epoch 3/10
# 60000/60000 [==============================] - 17s 291us/sample - loss: 0.2500 - accuracy: 0.9082 - val_loss: 0.3140 - val_accuracy: 0.8903
# Epoch 4/10
# 60000/60000 [==============================] - 18s 296us/sample - loss: 0.2279 - accuracy: 0.9173 - val_loss: 0.3208 - val_accuracy: 0.8889
# Epoch 5/10
# 60000/60000 [==============================] - 17s 290us/sample - loss: 0.2063 - accuracy: 0.9238 - val_loss: 0.3593 - val_accuracy: 0.8834
# Epoch 6/10
# 60000/60000 [==============================] - 18s 296us/sample - loss: 0.1886 - accuracy: 0.9309 - val_loss: 0.3500 - val_accuracy: 0.8881
# Epoch 7/10
# 60000/60000 [==============================] - 17s 291us/sample - loss: 0.1698 - accuracy: 0.9381 - val_loss: 0.3745 - val_accuracy: 0.8896
# Epoch 8/10
# 60000/60000 [==============================] - 18s 294us/sample - loss: 0.1637 - accuracy: 0.9405 - val_loss: 0.4138 - val_accuracy: 0.8922
# Epoch 9/10
# 60000/60000 [==============================] - 18s 299us/sample - loss: 0.1439 - accuracy: 0.9462 - val_loss: 0.4399 - val_accuracy: 0.8908
# Epoch 10/10
# 60000/60000 [==============================] - 18s 293us/sample - loss: 0.1349 - accuracy: 0.9512 - val_loss: 0.4483 - val_accuracy: 0.8853
# 10000/10000 - 1s - loss: 0.4483 - accuracy: 0.8853
# 60000/60000 - 6s - loss: 0.1393 - accuracy: 0.9460
# train accuracy:  0.94603336
# Test accuracy:  0.8853

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               692352
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 693,962
# Trainable params: 693,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_image(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return cv2.resize(img, (28,28))

# %%
images = np.array([get_image("C://Users//parit//OneDrive//Desktop//coat.png"), get_image("C://Users//parit//OneDrive//Desktop//ANK.png"), get_image("C://Users//parit//OneDrive//Desktop//bag.png"),get_image("C://Users//parit//OneDrive//Desktop//dress.png")])
plt.figure(figsize=(10,10))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(images[i], cmap=plt.cm.binary)
plt.show()
images_reshaped = images.reshape(images.shape[0], 28, 28,1)
images_reshaped = tf.cast(images_reshaped, tf.float32)

# %%
model = tf.keras.models.load_model("model.h5")
preds = model.predict(images_reshaped)

def plot_image(prediction, img):
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(prediction)
    plt.xlabel("{} {:2.0f}%".format(class_names[predicted_label],
               100*np.max(prediction),
               ),
                color="blue")

# %%
def plot_value_array(prediction):
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), prediction, color="#888888")
    plt.ylim([0,1])
    predicted_label = np.argmax(prediction)
    thisplot[predicted_label].set_color('blue')

# %%
plt.figure(figsize=(8,12))
for i in range(4):
    # image
    plt.subplot(4, 2, 2*i+1)
    plot_image(preds[i], images[i])
    # bar chart
    plt.subplot(4, 2, 2*i+2)
    plot_value_array(preds[i])
plt.show()
